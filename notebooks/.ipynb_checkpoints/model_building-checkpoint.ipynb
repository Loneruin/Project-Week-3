# %% [markdown]
# Build a regression model.

# %%
import pandas as pd
import json
import requests
from bs4 import BeautifulSoup
import scipy as sp
import numpy as np
import pandas as pd
from datetime import datetime
import pandas_profiling
import sqlite3
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
# %matplotlib inline

# %% [markdown]
# Provide model output and an interpretation of the results.

# %%
data = pd.read_csv('result4.csv')

# %%
data

# %%
sns.pairplot(data, x_vars = ['latitude','popularity','distance'], y_vars = ['rating'], height=3, aspect=0.7,kind='reg')

# %%
#We can see that there is a correlation between rating with popularity and distance of restaurants which are near bike station

# %%
feature_cols = ['latitude','popularity','distance']

# %%
X = data[feature_cols]

# %%
X

# %%
Y = data['rating']

# %%
Y

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X,Y,random_state=1)

# %%
from sklearn.linear_model import LinearRegression

# %%
linreg = LinearRegression()
linreg.fit(X_train,Y_train)
# Out:
# LinearRegression()

# %%
data_features = ['latitude', 'popularity','distance']
x = data[data_features]
y = data.rating

# %%
plt.subplot(2,2,1)
plt.scatter(x['latitude'],y)
plt.subplot(2,2,2)
plt.scatter(x['popularity'],y)
plt.subplot(2,2,3)
plt.scatter(x['distance'],y)

# %%
from mpl_toolkits.mplot3d import Axes3D

# %%
fig = plt.figure()
ax = fig.add_subplot(111, projection = "3d")

x1 = x['popularity']
x2 = x['distance']

ax.scatter(x1,x2,y, c="r", marker="o")
ax.set_xlabel('popularity')
ax.set_ylabel('distance')
ax.set_zlabel('rating')
# Out:
# Text(0.5, 0, 'rating')

# %% [markdown]
# # Stretch

# %% [markdown]
# How can you turn the regression model into a classification model?
